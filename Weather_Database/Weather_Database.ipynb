# %%
# Importing Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import gmaps
from config import g_key
import requests
import time
from scipy.stats import linregress

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 760

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping
# Processing Record 4 of Set 1 | kindu
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | kahta
# Processing Record 8 of Set 1 | rakitnoye
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | los llanos de aridane
# Processing Record 11 of Set 1 | frontera
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | trapani
# Processing Record 14 of Set 1 | yaan
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | mogadishu
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | staryy krym
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 27 of Set 1 | madoc
# Processing Record 28 of Set 1 | kargasok
# Processing Record 29 of Set 1 | trairi
# Processing Record 30 of Set 1 | taraz
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | virginia beach
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 34 of Set 1 | zachagansk
# City not found. Skipping
# Processing Record 35 of Set 1 | bokspits
# City not found. Skipping
# Processing Record 36 of Set 1 | strezhevoy
# Processing Record 37 of Set 1 | dondo
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | the valley
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | tarko-sale
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | olga
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | cockburn harbour
# City not found. Skipping
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | kamenka
# Processing Record 2 of Set 2 | mansa
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | batagay-alyta
# Processing Record 8 of Set 2 | xiongzhou
# Processing Record 9 of Set 2 | ngukurr
# City not found. Skipping
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | aloleng
# Processing Record 12 of Set 2 | masuguru
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | ocampo
# Processing Record 15 of Set 2 | kununurra
# Processing Record 16 of Set 2 | cockburn town
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | paide
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | paita
# Processing Record 21 of Set 2 | katherine
# Processing Record 22 of Set 2 | brae
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | tilichiki
# Processing Record 26 of Set 2 | kunyang
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | hirara
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | kushiro
# Processing Record 33 of Set 2 | acapulco
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping
# Processing Record 35 of Set 2 | bairiki
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | le port
# Processing Record 39 of Set 2 | eyl
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | sokoto
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | puerto leguizamo
# Processing Record 45 of Set 2 | fushun
# Processing Record 46 of Set 2 | arica
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | gwadar
# Processing Record 50 of Set 2 | ust-koksa
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | saint anthony
# Processing Record 3 of Set 3 | tumannyy
# City not found. Skipping
# Processing Record 4 of Set 3 | goycay
# City not found. Skipping
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | celestun
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | faanui
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | aberlour
# City not found. Skipping
# Processing Record 13 of Set 3 | miles city
# Processing Record 14 of Set 3 | lumut
# Processing Record 15 of Set 3 | lago da pedra
# Processing Record 16 of Set 3 | dong hoi
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | harper
# Processing Record 19 of Set 3 | mount isa
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | ambodifototra
# City not found. Skipping
# Processing Record 22 of Set 3 | ahuimanu
# Processing Record 23 of Set 3 | akureyri
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | ust-maya
# Processing Record 26 of Set 3 | chiredzi
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | barro
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 31 of Set 3 | umm lajj
# Processing Record 32 of Set 3 | bow island
# Processing Record 33 of Set 3 | sechura
# Processing Record 34 of Set 3 | santiago
# Processing Record 35 of Set 3 | luanda
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | maniitsoq
# Processing Record 38 of Set 3 | ongandjera
# Processing Record 39 of Set 3 | vallenar
# Processing Record 40 of Set 3 | satipo
# Processing Record 41 of Set 3 | puerto ayacucho
# Processing Record 42 of Set 3 | jarjis
# City not found. Skipping
# Processing Record 43 of Set 3 | kidal
# Processing Record 44 of Set 3 | zhigansk
# Processing Record 45 of Set 3 | salalah
# Processing Record 46 of Set 3 | tapes
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | yalta
# Processing Record 49 of Set 3 | meyungs
# City not found. Skipping
# Processing Record 50 of Set 3 | spornoye
# Processing Record 1 of Set 4 | port-cartier
# Processing Record 2 of Set 4 | bafq
# Processing Record 3 of Set 4 | turan
# Processing Record 4 of Set 4 | cangzhou
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | ballina
# Processing Record 11 of Set 4 | palamos
# Processing Record 12 of Set 4 | sibolga
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | mandalgovi
# Processing Record 15 of Set 4 | eldikan
# City not found. Skipping
# Processing Record 16 of Set 4 | padang
# Processing Record 17 of Set 4 | sao joao da barra
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | san matias
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | yeppoon
# Processing Record 23 of Set 4 | pelym
# Processing Record 24 of Set 4 | buala
# Processing Record 25 of Set 4 | benguela
# Processing Record 26 of Set 4 | haibowan
# City not found. Skipping
# Processing Record 27 of Set 4 | baykit
# Processing Record 28 of Set 4 | olafsvik
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | nguiu
# City not found. Skipping
# Processing Record 31 of Set 4 | conde
# Processing Record 32 of Set 4 | fort nelson
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | magadan
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | bulgan
# Processing Record 38 of Set 4 | moldova sulita
# Processing Record 39 of Set 4 | quatre cocos
# Processing Record 40 of Set 4 | machali
# Processing Record 41 of Set 4 | lazarev
# Processing Record 42 of Set 4 | marcona
# City not found. Skipping
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | bedele
# Processing Record 47 of Set 4 | sorvag
# City not found. Skipping
# Processing Record 48 of Set 4 | tabiauea
# City not found. Skipping
# Processing Record 49 of Set 4 | abha
# Processing Record 50 of Set 4 | santa vitoria do palmar
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping
# Processing Record 3 of Set 5 | fukue
# Processing Record 4 of Set 5 | durban
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | vicente guerrero
# Processing Record 7 of Set 5 | yumen
# Processing Record 8 of Set 5 | maryville
# Processing Record 9 of Set 5 | salinopolis
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | kuusamo
# Processing Record 12 of Set 5 | port macquarie
# Processing Record 13 of Set 5 | guymon
# Processing Record 14 of Set 5 | arak
# Processing Record 15 of Set 5 | dudinka
# Processing Record 16 of Set 5 | berlevag
# Processing Record 17 of Set 5 | lasa
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | luchenza
# Processing Record 20 of Set 5 | ambilobe
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | chiang mai
# Processing Record 23 of Set 5 | louisbourg
# City not found. Skipping
# Processing Record 24 of Set 5 | hambantota
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | bambui
# Processing Record 27 of Set 5 | brewster
# Processing Record 28 of Set 5 | bulungu
# Processing Record 29 of Set 5 | pemangkat
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | faya
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | bubaque
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | soyo
# Processing Record 38 of Set 5 | maryborough
# Processing Record 39 of Set 5 | livny
# Processing Record 40 of Set 5 | vestmannaeyjar
# Processing Record 41 of Set 5 | muli
# Processing Record 42 of Set 5 | najran
# Processing Record 43 of Set 5 | myitkyina
# Processing Record 44 of Set 5 | fare
# Processing Record 45 of Set 5 | camacha
# Processing Record 46 of Set 5 | kloulklubed
# Processing Record 47 of Set 5 | phan rang
# City not found. Skipping
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | cumaribo
# City not found. Skipping
# Processing Record 50 of Set 5 | cap-aux-meules
# Processing Record 1 of Set 6 | tidore
# City not found. Skipping
# Processing Record 2 of Set 6 | mahajanga
# Processing Record 3 of Set 6 | cairns
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | salta
# Processing Record 6 of Set 6 | raga
# Processing Record 7 of Set 6 | swakopmund
# Processing Record 8 of Set 6 | taoudenni
# Processing Record 9 of Set 6 | labuan
# Processing Record 10 of Set 6 | lityn
# Processing Record 11 of Set 6 | abnub
# Processing Record 12 of Set 6 | san felipe
# Processing Record 13 of Set 6 | xilagani
# Processing Record 14 of Set 6 | dera ismail khan
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | elizabeth city
# Processing Record 17 of Set 6 | port hedland
# Processing Record 18 of Set 6 | tuy hoa
# Processing Record 19 of Set 6 | udachnyy
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | ada
# Processing Record 22 of Set 6 | erdenet
# Processing Record 23 of Set 6 | nome
# Processing Record 24 of Set 6 | taltal
# Processing Record 25 of Set 6 | narsaq
# Processing Record 26 of Set 6 | vostok
# Processing Record 27 of Set 6 | tavares
# Processing Record 28 of Set 6 | gilgit
# Processing Record 29 of Set 6 | khatanga
# Processing Record 30 of Set 6 | champerico
# Processing Record 31 of Set 6 | svetlyy
# Processing Record 32 of Set 6 | mys shmidta
# City not found. Skipping
# Processing Record 33 of Set 6 | amancio
# City not found. Skipping
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | atuona
# Processing Record 36 of Set 6 | mahibadhoo
# Processing Record 37 of Set 6 | gat
# Processing Record 38 of Set 6 | codrington
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | vaitupu
# City not found. Skipping
# Processing Record 41 of Set 6 | hohhot
# Processing Record 42 of Set 6 | umaria
# Processing Record 43 of Set 6 | beernem
# Processing Record 44 of Set 6 | torbay
# Processing Record 45 of Set 6 | minggang
# Processing Record 46 of Set 6 | luohe
# Processing Record 47 of Set 6 | arnprior
# Processing Record 48 of Set 6 | mutsamudu
# City not found. Skipping
# Processing Record 49 of Set 6 | avinurme
# Processing Record 50 of Set 6 | lorengau
# Processing Record 1 of Set 7 | martapura
# Processing Record 2 of Set 7 | nuuk
# Processing Record 3 of Set 7 | kenai
# Processing Record 4 of Set 7 | bargal
# City not found. Skipping
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | mosquera
# Processing Record 7 of Set 7 | estrella
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | cabo rojo
# Processing Record 10 of Set 7 | san policarpo
# Processing Record 11 of Set 7 | bang saphan
# Processing Record 12 of Set 7 | mukhen
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | angoram
# Processing Record 15 of Set 7 | warora
# Processing Record 16 of Set 7 | san cristobal
# Processing Record 17 of Set 7 | labuhan
# Processing Record 18 of Set 7 | goure
# Processing Record 19 of Set 7 | nanortalik
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | coquimbo
# Processing Record 22 of Set 7 | half moon bay
# Processing Record 23 of Set 7 | talara
# Processing Record 24 of Set 7 | lolua
# City not found. Skipping
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | alice springs
# Processing Record 27 of Set 7 | kontagora
# Processing Record 28 of Set 7 | kiama
# Processing Record 29 of Set 7 | hovd
# Processing Record 30 of Set 7 | paamiut
# Processing Record 31 of Set 7 | koslan
# Processing Record 32 of Set 7 | davila
# Processing Record 33 of Set 7 | aklavik
# Processing Record 34 of Set 7 | forio
# Processing Record 35 of Set 7 | teluknaga
# Processing Record 36 of Set 7 | abu dhabi
# Processing Record 37 of Set 7 | lisala
# Processing Record 38 of Set 7 | camabatela
# Processing Record 39 of Set 7 | pedro carbo
# Processing Record 40 of Set 7 | leningradskiy
# Processing Record 41 of Set 7 | sao caetano de odivelas
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | tunxi
# City not found. Skipping
# Processing Record 44 of Set 7 | ilulissat
# Processing Record 45 of Set 7 | ketchikan
# Processing Record 46 of Set 7 | upata
# Processing Record 47 of Set 7 | talnakh
# Processing Record 48 of Set 7 | grand gaube
# Processing Record 49 of Set 7 | noumea
# Processing Record 50 of Set 7 | ixtapa
# Processing Record 1 of Set 8 | adrar
# Processing Record 2 of Set 8 | labytnangi
# Processing Record 3 of Set 8 | puerto pinasco
# City not found. Skipping
# Processing Record 4 of Set 8 | dengfeng
# Processing Record 5 of Set 8 | skibbereen
# Processing Record 6 of Set 8 | corrales
# Processing Record 7 of Set 8 | gimli
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping
# Processing Record 9 of Set 8 | durg
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | havoysund
# Processing Record 12 of Set 8 | ucluelet
# Processing Record 13 of Set 8 | xining
# Processing Record 14 of Set 8 | pogranichnyy
# Processing Record 15 of Set 8 | mayumba
# Processing Record 16 of Set 8 | kuyanovo
# Processing Record 17 of Set 8 | henties bay
# Processing Record 18 of Set 8 | xiongshi
# City not found. Skipping
# Processing Record 19 of Set 8 | airai
# Processing Record 20 of Set 8 | killybegs
# Processing Record 21 of Set 8 | roncq
# Processing Record 22 of Set 8 | ostrovnoy
# Processing Record 23 of Set 8 | cidreira
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | massaguet
# Processing Record 26 of Set 8 | longyearbyen
# Processing Record 27 of Set 8 | adilabad
# Processing Record 28 of Set 8 | laredo
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | ndioum
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | tauranga
# Processing Record 33 of Set 8 | banjar
# Processing Record 34 of Set 8 | krasnyy profintern
# Processing Record 35 of Set 8 | kharp
# Processing Record 36 of Set 8 | gilbues
# Processing Record 37 of Set 8 | beloha
# Processing Record 38 of Set 8 | muroto
# Processing Record 39 of Set 8 | biltine
# Processing Record 40 of Set 8 | llanes
# Processing Record 41 of Set 8 | ewa beach
# Processing Record 42 of Set 8 | manitouwadge
# Processing Record 43 of Set 8 | mehtar lam
# Processing Record 44 of Set 8 | kavieng
# Processing Record 45 of Set 8 | tual
# Processing Record 46 of Set 8 | flin flon
# Processing Record 47 of Set 8 | inuvik
# Processing Record 48 of Set 8 | kupino
# Processing Record 49 of Set 8 | rapla
# Processing Record 50 of Set 8 | ihlow
# Processing Record 1 of Set 9 | verkhoyansk
# Processing Record 2 of Set 9 | chimbote
# Processing Record 3 of Set 9 | warqla
# City not found. Skipping
# Processing Record 4 of Set 9 | swan hill
# Processing Record 5 of Set 9 | mizdah
# Processing Record 6 of Set 9 | meadow lake
# Processing Record 7 of Set 9 | attawapiskat
# City not found. Skipping
# Processing Record 8 of Set 9 | jibuti
# Processing Record 9 of Set 9 | bac lieu
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | nigde
# Processing Record 12 of Set 9 | mayo
# Processing Record 13 of Set 9 | bontang
# Processing Record 14 of Set 9 | colares
# Processing Record 15 of Set 9 | lithgow
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | namatanai
# Processing Record 18 of Set 9 | yurimaguas
# Processing Record 19 of Set 9 | mwense
# Processing Record 20 of Set 9 | agadez
# Processing Record 21 of Set 9 | bataipora
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | tres arroyos
# Processing Record 24 of Set 9 | usinsk
# Processing Record 25 of Set 9 | nara
# Processing Record 26 of Set 9 | ghanzi
# Processing Record 27 of Set 9 | victoria point
# Processing Record 28 of Set 9 | olavarria
# Processing Record 29 of Set 9 | siocon
# Processing Record 30 of Set 9 | swift current
# Processing Record 31 of Set 9 | vila velha
# Processing Record 32 of Set 9 | loandjili
# Processing Record 33 of Set 9 | constantine
# Processing Record 34 of Set 9 | caravelas
# Processing Record 35 of Set 9 | nanma
# Processing Record 36 of Set 9 | cherat
# Processing Record 37 of Set 9 | mocambique
# City not found. Skipping
# Processing Record 38 of Set 9 | srednekolymsk
# Processing Record 39 of Set 9 | fez
# Processing Record 40 of Set 9 | omboue
# Processing Record 41 of Set 9 | whitianga
# Processing Record 42 of Set 9 | husum
# Processing Record 43 of Set 9 | jinchengjiang
# City not found. Skipping
# Processing Record 44 of Set 9 | eureka
# Processing Record 45 of Set 9 | shimoda
# Processing Record 46 of Set 9 | huazolotitlan
# City not found. Skipping
# Processing Record 47 of Set 9 | san quintin
# Processing Record 48 of Set 9 | santa ines
# Processing Record 49 of Set 9 | kahului
# Processing Record 50 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 10 | opobo
# City not found. Skipping
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | amos
# Processing Record 4 of Set 10 | malchin
# Processing Record 5 of Set 10 | kadykchan
# City not found. Skipping
# Processing Record 6 of Set 10 | san ramon
# Processing Record 7 of Set 10 | kasungu
# Processing Record 8 of Set 10 | lompoc
# Processing Record 9 of Set 10 | faridkot
# Processing Record 10 of Set 10 | kindia
# Processing Record 11 of Set 10 | fort morgan
# Processing Record 12 of Set 10 | tubruq
# City not found. Skipping
# Processing Record 13 of Set 10 | yarmouth
# Processing Record 14 of Set 10 | chuy
# Processing Record 15 of Set 10 | ciro marina
# Processing Record 16 of Set 10 | antalaha
# Processing Record 17 of Set 10 | formiga
# Processing Record 18 of Set 10 | kiruna
# Processing Record 19 of Set 10 | aripuana
# Processing Record 20 of Set 10 | gamba
# Processing Record 21 of Set 10 | golden
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | nizhniy ingash
# Processing Record 24 of Set 10 | kailua
# Processing Record 25 of Set 10 | luderitz
# Processing Record 26 of Set 10 | xiamen
# Processing Record 27 of Set 10 | dunedin
# Processing Record 28 of Set 10 | cartagena del chaira
# Processing Record 29 of Set 10 | bambanglipuro
# Processing Record 30 of Set 10 | kirovskiy
# Processing Record 31 of Set 10 | bowen
# Processing Record 32 of Set 10 | atar
# Processing Record 33 of Set 10 | bocaranga
# City not found. Skipping
# Processing Record 34 of Set 10 | altay
# Processing Record 35 of Set 10 | papasquiaro
# City not found. Skipping
# Processing Record 36 of Set 10 | bay roberts
# Processing Record 37 of Set 10 | saint-pierre
# Processing Record 38 of Set 10 | husavik
# Processing Record 39 of Set 10 | chama
# Processing Record 40 of Set 10 | ariquemes
# Processing Record 41 of Set 10 | parana
# Processing Record 42 of Set 10 | tecpan
# Processing Record 43 of Set 10 | aldan
# Processing Record 44 of Set 10 | fortuna
# Processing Record 45 of Set 10 | queenstown
# Processing Record 46 of Set 10 | burhaniye
# Processing Record 47 of Set 10 | voh
# Processing Record 48 of Set 10 | hailar
# Processing Record 49 of Set 10 | kawalu
# Processing Record 50 of Set 10 | balakhninskiy
# Processing Record 1 of Set 11 | erenhot
# Processing Record 2 of Set 11 | san buenaventura
# Processing Record 3 of Set 11 | saryshagan
# City not found. Skipping
# Processing Record 4 of Set 11 | neuquen
# Processing Record 5 of Set 11 | amurzet
# Processing Record 6 of Set 11 | aleksandrov gay
# Processing Record 7 of Set 11 | van
# Processing Record 8 of Set 11 | katsuura
# Processing Record 9 of Set 11 | bathsheba
# Processing Record 10 of Set 11 | sisimiut
# Processing Record 11 of Set 11 | yinchuan
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | marzuq
# Processing Record 14 of Set 11 | iqaluit
# Processing Record 15 of Set 11 | grafton
# Processing Record 16 of Set 11 | abalak
# Processing Record 17 of Set 11 | evensk
# Processing Record 18 of Set 11 | inongo
# Processing Record 19 of Set 11 | alugan
# Processing Record 20 of Set 11 | bardiyah
# Processing Record 21 of Set 11 | namalenga
# Processing Record 22 of Set 11 | eldorado
# Processing Record 23 of Set 11 | burgeo
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | kantunilkin
# Processing Record 26 of Set 11 | estelle
# Processing Record 27 of Set 11 | sampit
# Processing Record 28 of Set 11 | shenjiamen
# Processing Record 29 of Set 11 | yuli
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | broken hill
# Processing Record 32 of Set 11 | chagda
# City not found. Skipping
# Processing Record 33 of Set 11 | ratnagiri
# Processing Record 34 of Set 11 | olenegorsk
# Processing Record 35 of Set 11 | tateyama
# Processing Record 36 of Set 11 | buique
# Processing Record 37 of Set 11 | opuwo
# Processing Record 38 of Set 11 | la ronge
# Processing Record 39 of Set 11 | harnai
# Processing Record 40 of Set 11 | montrose
# Processing Record 41 of Set 11 | anjiang
# Processing Record 42 of Set 11 | zlatoustovsk
# City not found. Skipping
# Processing Record 43 of Set 11 | mujiayingzi
# Processing Record 44 of Set 11 | trastenik
# Processing Record 45 of Set 11 | cuamba
# Processing Record 46 of Set 11 | am timan
# Processing Record 47 of Set 11 | cabo san lucas
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | fort saint james
# Processing Record 50 of Set 11 | ca mau
# Processing Record 1 of Set 12 | lebu
# Processing Record 2 of Set 12 | bonthe
# Processing Record 3 of Set 12 | antofagasta
# Processing Record 4 of Set 12 | mongoumba
# Processing Record 5 of Set 12 | maracas
# Processing Record 6 of Set 12 | banda aceh
# Processing Record 7 of Set 12 | chabahar
# Processing Record 8 of Set 12 | tondano
# Processing Record 9 of Set 12 | tromso
# Processing Record 10 of Set 12 | palu
# Processing Record 11 of Set 12 | wanaka
# Processing Record 12 of Set 12 | meulaboh
# Processing Record 13 of Set 12 | emba
# Processing Record 14 of Set 12 | upington
# Processing Record 15 of Set 12 | morehead
# Processing Record 16 of Set 12 | richards bay
# Processing Record 17 of Set 12 | jabinyanah
# Processing Record 18 of Set 12 | port lavaca
# Processing Record 19 of Set 12 | morris
# Processing Record 20 of Set 12 | tibati
# Processing Record 21 of Set 12 | lotofaga
# Processing Record 22 of Set 12 | manicore
# Processing Record 23 of Set 12 | paoua
# Processing Record 24 of Set 12 | dekar
# Processing Record 25 of Set 12 | taksimo
# Processing Record 26 of Set 12 | bonfim
# Processing Record 27 of Set 12 | kalanguy
# Processing Record 28 of Set 12 | vardo
# Processing Record 29 of Set 12 | vuktyl
# Processing Record 30 of Set 12 | eenhana
# Processing Record 31 of Set 12 | zhezkazgan
# Processing Record 32 of Set 12 | asfi
# Processing Record 33 of Set 12 | ekhabi
# Processing Record 34 of Set 12 | terney
# Processing Record 35 of Set 12 | general pico
# Processing Record 36 of Set 12 | kudat
# Processing Record 37 of Set 12 | sidney
# Processing Record 38 of Set 12 | tuysarkan
# City not found. Skipping
# Processing Record 39 of Set 12 | iwanai
# Processing Record 40 of Set 12 | fevralsk
# City not found. Skipping
# Processing Record 41 of Set 12 | bloemhof
# Processing Record 42 of Set 12 | ozernovskiy
# Processing Record 43 of Set 12 | anchorage
# Processing Record 44 of Set 12 | aflu
# City not found. Skipping
# Processing Record 45 of Set 12 | port victoria
# Processing Record 46 of Set 12 | sao jose da coroa grande
# Processing Record 47 of Set 12 | kaohsiung
# Processing Record 48 of Set 12 | komsomolskiy
# Processing Record 49 of Set 12 | serik
# Processing Record 50 of Set 12 | cabadiangan
# Processing Record 1 of Set 13 | springdale
# Processing Record 2 of Set 13 | abu samrah
# Processing Record 3 of Set 13 | toliary
# City not found. Skipping
# Processing Record 4 of Set 13 | margate
# Processing Record 5 of Set 13 | taburi
# City not found. Skipping
# Processing Record 6 of Set 13 | arman
# Processing Record 7 of Set 13 | mapastepec
# Processing Record 8 of Set 13 | dhangadhi
# Processing Record 9 of Set 13 | horta
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | dzilam gonzalez
# Processing Record 12 of Set 13 | sao raimundo nonato
# Processing Record 13 of Set 13 | sao sebastiao do paraiso
# Processing Record 14 of Set 13 | mandan
# Processing Record 15 of Set 13 | qaqortoq
# Processing Record 16 of Set 13 | kuytun
# Processing Record 17 of Set 13 | suseni
# Processing Record 18 of Set 13 | darnah
# Processing Record 19 of Set 13 | manaquiri
# Processing Record 20 of Set 13 | timmins
# Processing Record 21 of Set 13 | hastings
# Processing Record 22 of Set 13 | vao
# Processing Record 23 of Set 13 | nhulunbuy
# Processing Record 24 of Set 13 | manokwari
# Processing Record 25 of Set 13 | cap malheureux
# Processing Record 26 of Set 13 | goderich
# Processing Record 27 of Set 13 | rajpur
# Processing Record 28 of Set 13 | tigil
# Processing Record 29 of Set 13 | kargopol
# Processing Record 30 of Set 13 | zhanaozen
# Processing Record 31 of Set 13 | simpang
# Processing Record 32 of Set 13 | el faiyum
# City not found. Skipping
# Processing Record 33 of Set 13 | tura
# Processing Record 34 of Set 13 | tazovskiy
# Processing Record 35 of Set 13 | golpayegan
# Processing Record 36 of Set 13 | peniche
# Processing Record 37 of Set 13 | quetzaltepec
# City not found. Skipping
# Processing Record 38 of Set 13 | suclayin
# Processing Record 39 of Set 13 | sambava
# Processing Record 40 of Set 13 | xingyi
# Processing Record 41 of Set 13 | novaya igirma
# Processing Record 42 of Set 13 | ostersund
# Processing Record 43 of Set 13 | ovre ardal
# Processing Record 44 of Set 13 | lieksa
# Processing Record 45 of Set 13 | beroroha
# Processing Record 46 of Set 13 | pringsewu
# Processing Record 47 of Set 13 | bequimao
# Processing Record 48 of Set 13 | shubarshi
# Processing Record 49 of Set 13 | ahipara
# Processing Record 50 of Set 13 | dolbeau
# City not found. Skipping
# Processing Record 1 of Set 14 | warrnambool
# Processing Record 2 of Set 14 | agaro
# Processing Record 3 of Set 14 | bull savanna
# Processing Record 4 of Set 14 | pitimbu
# Processing Record 5 of Set 14 | ternate
# Processing Record 6 of Set 14 | denpasar
# Processing Record 7 of Set 14 | quang ngai
# Processing Record 8 of Set 14 | luxeuil-les-bains
# Processing Record 9 of Set 14 | dubrovnik
# Processing Record 10 of Set 14 | kuruman
# Processing Record 11 of Set 14 | sao felix do xingu
# Processing Record 12 of Set 14 | majalaya
# Processing Record 13 of Set 14 | maningrida
# Processing Record 14 of Set 14 | port shepstone
# Processing Record 15 of Set 14 | thaba-tseka
# Processing Record 16 of Set 14 | kamien pomorski
# Processing Record 17 of Set 14 | gurgan
# City not found. Skipping
# Processing Record 18 of Set 14 | nioro
# Processing Record 19 of Set 14 | rocha
# Processing Record 20 of Set 14 | mapiripan
# Processing Record 21 of Set 14 | xiangdong
# City not found. Skipping
# Processing Record 22 of Set 14 | beryslav
# Processing Record 23 of Set 14 | nenjiang
# Processing Record 24 of Set 14 | sarahan
# Processing Record 25 of Set 14 | heinola
# Processing Record 26 of Set 14 | lagoa
# Processing Record 27 of Set 14 | itaituba
# Processing Record 28 of Set 14 | pawa
# Processing Record 29 of Set 14 | senmonorom
# City not found. Skipping
# Processing Record 30 of Set 14 | sirmaur
# Processing Record 31 of Set 14 | pryazha
# Processing Record 32 of Set 14 | saleaula
# City not found. Skipping
# Processing Record 33 of Set 14 | dapaong
# Processing Record 34 of Set 14 | yaring
# Processing Record 35 of Set 14 | kulhudhuffushi
# Processing Record 36 of Set 14 | hami
# Processing Record 37 of Set 14 | fonte boa
# Processing Record 38 of Set 14 | koudougou
# Processing Record 39 of Set 14 | alofi
# Processing Record 40 of Set 14 | muzhi
# Processing Record 41 of Set 14 | hualmay
# Processing Record 42 of Set 14 | sitia
# Processing Record 43 of Set 14 | birin
# Processing Record 44 of Set 14 | karauzyak
# City not found. Skipping
# Processing Record 45 of Set 14 | saint george
# Processing Record 46 of Set 14 | gualaquiza
# Processing Record 47 of Set 14 | samusu
# City not found. Skipping
# Processing Record 48 of Set 14 | auki
# Processing Record 49 of Set 14 | sarankhola
# Processing Record 50 of Set 14 | hofn
# Processing Record 1 of Set 15 | vanimo
# Processing Record 2 of Set 15 | capaccio
# Processing Record 3 of Set 15 | kuryk
# Processing Record 4 of Set 15 | at-bashi
# Processing Record 5 of Set 15 | ambanja
# Processing Record 6 of Set 15 | karratha
# Processing Record 7 of Set 15 | vohibinany
# Processing Record 8 of Set 15 | yuzhou
# Processing Record 9 of Set 15 | flagstaff
# Processing Record 10 of Set 15 | cheuskiny
# City not found. Skipping
# Processing Record 11 of Set 15 | agua verde
# Processing Record 12 of Set 15 | burgdorf
# Processing Record 13 of Set 15 | palembang
# Processing Record 14 of Set 15 | slave lake
# Processing Record 15 of Set 15 | luancheng
# Processing Record 16 of Set 15 | avera
# Processing Record 17 of Set 15 | tanete
# Processing Record 18 of Set 15 | wairoa
# Processing Record 19 of Set 15 | ankpa
# Processing Record 20 of Set 15 | san carlos
# Processing Record 21 of Set 15 | tanjong karang
# City not found. Skipping
# Processing Record 22 of Set 15 | miraflores
# Processing Record 23 of Set 15 | sharjah
# Processing Record 24 of Set 15 | los algarrobos
# Processing Record 25 of Set 15 | baculin
# Processing Record 26 of Set 15 | roma
# Processing Record 27 of Set 15 | erzincan
# Processing Record 28 of Set 15 | aberystwyth
# Processing Record 29 of Set 15 | gallup
# Processing Record 30 of Set 15 | orange walk
# Processing Record 31 of Set 15 | canon city
# Processing Record 32 of Set 15 | san julian
# Processing Record 33 of Set 15 | buta
# Processing Record 34 of Set 15 | angra dos reis
# Processing Record 35 of Set 15 | kamloops
# Processing Record 36 of Set 15 | hervey bay
# Processing Record 37 of Set 15 | waingapu
# Processing Record 38 of Set 15 | ust-kuyga
# Processing Record 39 of Set 15 | rongcheng
# Processing Record 40 of Set 15 | ardistan
# City not found. Skipping
# Processing Record 41 of Set 15 | miri
# Processing Record 42 of Set 15 | jiwani
# Processing Record 43 of Set 15 | kauhajoki
# Processing Record 44 of Set 15 | puerto madero
# Processing Record 45 of Set 15 | jabiru
# City not found. Skipping
# Processing Record 46 of Set 15 | lazaro cardenas
# Processing Record 47 of Set 15 | tarauaca
# Processing Record 48 of Set 15 | salym
# Processing Record 49 of Set 15 | san andres
# Processing Record 50 of Set 15 | valparaiso
# Processing Record 1 of Set 16 | payo
# Processing Record 2 of Set 16 | shahrud
# Processing Record 3 of Set 16 | pinawa
# Processing Record 4 of Set 16 | paredon
# Processing Record 5 of Set 16 | awbari
# Processing Record 6 of Set 16 | kudahuvadhoo
# Processing Record 7 of Set 16 | sudbury
# Processing Record 8 of Set 16 | tundla
# Processing Record 9 of Set 16 | ciudad valles
# Processing Record 10 of Set 16 | hay river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                     City Country                 Date      Lat       Lng  \
# 0                Mataura      NZ  2022-09-11 22:21:08 -46.1927  168.8643
# 1           Puerto Ayora      EC  2022-09-11 22:19:09  -0.7393  -90.3518
# 2                  Kindu      CD  2022-09-11 22:21:09  -2.9500   25.9500
# 3         Saint-Philippe      RE  2022-09-11 22:21:10 -21.3585   55.7679
# 4            Clyde River      CA  2022-09-11 22:21:10  70.4692  -68.5914
# 5                  Kahta      TR  2022-09-11 22:21:10  37.7855   38.6237
# 6              Rakitnoye      RU  2022-09-11 22:21:11  50.8389   35.8515
# 7              Mahebourg      MU  2022-09-11 22:21:11 -20.4081   57.7000
# 8  Los Llanos De Aridane      ES  2022-09-11 22:21:12  28.6585  -17.9182
# 9               Frontera      MX  2022-09-11 22:21:12  26.9333 -101.4500
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     48.47        62         100        1.97          light rain
# 1     75.16        86          75        5.01       broken clouds
# 2     69.75        98          91        1.30       moderate rain
# 3     67.59        80          37        8.63    scattered clouds
# 4     39.43       100         100        5.75     overcast clouds
# 5     79.97        18           0        1.52           clear sky
# 6     55.36        39         100       13.18     overcast clouds
# 7     70.09        78          75        3.44       broken clouds
# 8     71.35        93           0        3.44           clear sky
# 9     89.35        40          75       11.50       broken clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
